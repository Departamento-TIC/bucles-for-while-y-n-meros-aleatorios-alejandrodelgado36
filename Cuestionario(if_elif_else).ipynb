# %% [markdown]
# <a href="https://colab.research.google.com/github/Departamento-TIC/bucles-for-while-y-n-meros-aleatorios-alejandrodelgado36/blob/main/Cuestionario(if_elif_else).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Lab 3: Créate un Cuestionario [Programar Juegos Arcade con Python y Pygame](http://programarcadegames.com/index.php)
#
#
# #Descripción
# Estas son las características que debe tener tu cuestionario:
#
#
# 1.   Créalo con cinco o más preguntas. Puedes preguntar cosas que requieran
# *   un número como respuesta (por ejemplo; ¿Cuánto es 1+1?)
# *   texto (Por ejemplo; ¿Cuál es el apellido de Harry Potter?)
# *   una selección (¿Cuál de estas opciones son las correctas A, B, o C?)
#
# 2.   Si permites que el usuario introduzca respuestas no numéricas, piensa y cubre las distintas formas en que podría contestar. Por ejemplo, si la respuesta es “a”, sería aceptable también “A”? Échale un vistazo a la Sección 3.6 para que recuerdes cómo conseguir esto.
#
# 3. Debes permitir que el usuario sepa que ha acertado con la respuesta correcta. Imprime un mensaje basado en esa respuesta.
# 4. Debes llevar la cuenta del número de respuestas acertadas.
# 5. Al final del programa, deberás mostrar el porcentaje de respuestas contestadas correctamente por el usuario.
#
# #Ejemplo de ejecución
#
# ```
# ¡A jugar!
#
# ¿De cuántos libros consta la serie de Harry Potter? 7
# Correcto!
#
# ¿Cuánto es 3*(2-1)? 3
# Correcto!
#
# ¿Cuánto es 3*2-1? 5
# Correcto!
#
# ¿Quién canta Black Horse and the Cherry Tree?
# 1. Kelly Clarkson
# 2. K.T. Tunstall
# 3. Hillary Duff
# 4. Bon Jovi
# ? 2
# Correcto!
#
# ¿Qué personaje aparece en el billete de un dólar?
# 1. George Washington
# 2. Abraham Lincoln
# 3. John Adams
# 4. Thomas Jefferson
# ? 2
# No.
#
# Mis felicitaciones, has conseguido 4 respuestas correctas!
# Eso es una puntuación del 80 por ciento.
# ```

# %% [markdown]
# # Crea un celda de código debajo y escribe allí tu programa

# %%
print('A jugar!')
rc = 0

r1 = int(input('¿Cuantos estados hay en EEUU? '))

if r1 == 50:
  print('¡Correcto!')
  rc += 1
else:
  print('Incorrecto, la respuesta es 50.')

r2 = input('¿Cómo se llamaba el escritor español que nacío en Moguer? ')

if r2 == 'Juan Ramón':
  print('¡Correcto!')
  rc += 1
elif r2 == 'Juan Ramón Jiménez':
  print('!Correcto!')
  rc += 1
else:
  print('Incorrecto, la respuesta es Juan Ramón Jiménez')

r3 = (input('Cuanto es 125//25 + 8//4: '))

if r3 == '7':
  print('¡Correcto!')
  rc += 1
else:
  print('Incorrecto, la respuesta es 7')

print('¿Quién no es futbolista?')
print('1. Cristiano Ronaldo.')
print('2. Leo Messi.')
print('3. Vinicius.')
print('4. Lebron James')
r4 = (input('Escribe aquí tu respuesta. '))
if r4 == '1':
  print('Incorrecto, la respuesta es Lebron James.')
elif r4 == '2':
  print('Incorrecto, la respuesta es Lebron James.')
elif r4 == '3':
  print('Futbolista pésimo pero futbolista al fin y al cabo, la respuesta es Lebron James.')
elif r4 == '4':
  print('¡Correcto!')
  rc += 1
else:
  print('Repuesta inválida')
print('¿Cúal de estos libros fue escrito por Herman Melville?')
print('A. Wuthering Heights.')
print('B. Don Quijote.')
print('C. Moby Dick.')
r5 = input('Escribe aquí tu respuesta. ')
if r5 == 'A' or 'a':
  print('Incorrecto, la respuesta es Moby Dick.')
elif r5 == 'B' or 'b':
  print('Incorrecto, la respuesta es Moby Dick.')
elif r5 == 'C' or 'c':
  print('¡Correcto!')
  rc += 1
else:
  print('Respuesta inválida')
print('Tu puntuación total es: ', rc)
pf = float((rc /5) * 100)
print('Tu porcentaje de aciertos es del ', pf)
# Out:
# A jugar!
# ¿Cuantos estados hay en EEUU? 2
# Incorrecto, la respuesta es 50.
# ¿Cómo se llamaba el escritor español que nacío en Moguer? 2
# Incorrecto, la respuesta es Juan Ramón Jiménez
# Cuanto es 125//25 + 8//4: 2
# Incorrecto, la respuesta es 7
# ¿Quién no es futbolista?
# 1. Cristiano Ronaldo.
# 2. Leo Messi.
# 3. Vinicius.
# 4. Lebron James
# Escribe aquí tu respuesta. 2
# Incorrecto, la respuesta es Lebron James.
# ¿Cúal de estos libros fue escrito por Herman Melville?
# A. Wuthering Heights.
# B. Don Quijote.
# C. Moby Dick.
# Escribe aquí tu respuesta. c
# Incorrecto, la respuesta es Moby Dick.
# Tu puntuación total es:  0
# Tu porcentaje de aciertos es del  0.0
